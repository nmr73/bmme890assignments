# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# %matplotlib inline

# %%
dftrain = pd.read_csv('train.csv')
dftest = pd.read_csv('test.csv')

dftrain['train'] = 1
dftest['train'] = 0

y = dftrain['SalePrice']
dftrain = dftrain.drop(columns = ['SalePrice'])

dfcomb = pd.concat([dftrain,dftest])
# dfcomb = dftrain.merge(dftest,how='left')
dfcomb.reset_index(drop=True)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
dfcomb.columns
#many features, decent feature engineering will be key
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
dfcomb.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000  ...
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235  ...
# std       1.113131    30.291442     20.894344   179.334253   455.610826  ...
# ...

# %% [markdown]
# ## Check dependent variable

# %%
y.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# ## Check for Missing Data (only use Training set)

# %%
#check for missing data
null_columns=dftrain.columns[dftrain.isnull().any()]
total = dftrain.isnull().sum().sort_values(ascending=False)
percent = (dftrain.isnull().sum()/dftrain.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageYrBlt      81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtExposure     38  0.026027
# BsmtFinType2     38  0.026027
# BsmtFinType1     37  0.025342
# BsmtCond         37  0.025342
# BsmtQual         37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Utilities         0  0.000000

# %% [markdown]
# Garage all have same number of missing values. Let's drop columns with more than 10% missing data (146).
# For the rest of data, fill in with the mode for that category or the median if numerical.

# %%
#drop ones with more than 10% values missing data (146)
dropcols = ['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage']
dfcomb = dfcomb.drop(dropcols,axis=1)

#if we're dropping Misc features we should drop the Misc feature values as well since they're closely related
dfcomb = dfcomb.drop('MiscVal',axis=1)

# %% [markdown]
# Note, looking at the data itself, Kitchen & Bedrooms are in the description but don't actually show up in the data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder

# %% [markdown]
# #### Impute for Numerical/Categorical; Scale for Numerical

# %%
#separate feature types
numericfeat = (['LotArea','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1',
              'BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF',
                'GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath',
                'TotRmsAbvGrd','Fireplaces','GarageYrBlt','GarageCars','GarageArea',
                'WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea',
               'MoSold','YrSold','OverallQual','OverallCond'])
               
categfeat = (['MSSubClass','MSZoning','Street','LandContour','Utilities','LotConfig',
            'Neighborhood','Condition1','Condition2','BldgType','RoofStyle','RoofMatl',
             'Exterior1st','Exterior2nd','MasVnrType','Foundation','Heating','CentralAir',
              'Electrical','GarageType','PavedDrive','SaleType','SaleCondition','HouseStyle'])

ordfeat = (['LotShape','LandSlope','ExterQual','ExterCond',
           'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','HeatingQC','KitchenQual',
            'Functional','GarageFinish','GarageQual','GarageCond'])

# %%
#numerical -> median
imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
dfcomb[numericfeat] = imp_med.fit_transform(dfcomb[numericfeat])
scaler = StandardScaler()
dfcomb[numericfeat] = scaler.fit_transform(dfcomb[numericfeat])

#categorical/ordinal -> mode
imp_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
#trainset
dfcomb[categfeat] = imp_mode.fit_transform(dfcomb[categfeat])
dfcomb[ordfeat] = imp_mode.fit_transform(dfcomb[ordfeat])

# %%
#check missing values gone
null_columns=dfcomb.columns[dfcomb.isnull().any()]
total = dfcomb.isnull().sum().sort_values(ascending=False)
percent = (dfcomb.isnull().sum()/dfcomb.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(5)
# Out:
#               Total  Percent
# train             0      0.0
# YearRemodAdd      0      0.0
# RoofMatl          0      0.0
# Exterior1st       0      0.0
# Exterior2nd       0      0.0

# %% [markdown]
# #### One-Hot Encode Categorical Features

# %%
dfcombcategohe = pd.get_dummies(dfcomb[categfeat])
dfcomb = pd.concat([dfcomb,dfcombcategohe], axis=1)
dfcomb.drop(categfeat,axis=1,inplace=True)

# %% [markdown]
# #### Create Custom Scalings for Ordinal Features & Encode for Each

# %%
# ordfeat = (['LotShape','LandSlope','ExterQual','ExterCond',
#            'BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','HeatingQC','KitchenQual',
#             'Functional','GarageFinish','GarageQual','GarageCond'])

LShape = [['Reg',1],['IR1',2],['IR2',3],['IR3',4]]
enc = OrdinalEncoder()
enc.fit(LShape)
tmp = dfcomb['LotShape'].values.reshape(-1, 1)
dfcomb['LotShape'] = enc.fit_transform(tmp,y=None)

LSlope = [['Gtl',1],['Mod',2],['Sev',3]]
enc = OrdinalEncoder()
enc.fit(LSlope)
tmp = dfcomb['LandSlope'].values.reshape(-1, 1)
dfcomb['LandSlope'] = enc.fit_transform(tmp,y=None)

ExQual = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5]]
enc = OrdinalEncoder()
enc.fit(ExQual)
tmp = dfcomb['ExterQual'].values.reshape(-1, 1)
dfcomb['ExterQual'] = enc.fit_transform(tmp,y=None)

ExCond = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5]]
enc = OrdinalEncoder()
enc.fit(ExCond)
tmp = dfcomb['ExterCond'].values.reshape(-1, 1)
dfcomb['ExterCond'] = enc.fit_transform(tmp,y=None)

BsQual = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5],['NA',6]]
enc.fit(BsQual)
tmp = dfcomb['BsmtQual'].values.reshape(-1, 1)
dfcomb['BsmtQual'] = enc.fit_transform(tmp,y=None)

BsCond = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5],['NA',6]]
enc.fit(BsCond)
tmp = dfcomb['BsmtCond'].values.reshape(-1, 1)
dfcomb['BsmtCond'] = enc.fit_transform(tmp,y=None)

BsExpo = [['Gd',1],['Av',2],['Mn',3],['No',4],['NA',5]]
enc = OrdinalEncoder()
enc.fit(BsExpo)
tmp = dfcomb['BsmtExposure'].values.reshape(-1, 1)
dfcomb['BsmtExposure'] = enc.fit_transform(tmp,y=None)

BsFin1 = [['GLQ',1],['ALQ',2],['BLQ',3],['Rec',4],['LwQ',5],['Unf',6],['NA',7]]
enc = OrdinalEncoder()
enc.fit(BsFin1)
tmp = dfcomb['BsmtFinType1'].values.reshape(-1, 1)
dfcomb['BsmtFinType1'] = enc.fit_transform(tmp,y=None)

BsFin2 = [['GLQ',1],['ALQ',2],['BLQ',3],['Rec',4],['LwQ',5],['Unf',6],['NA',7]]
enc = OrdinalEncoder()
enc.fit(BsFin2)
tmp = dfcomb['BsmtFinType2'].values.reshape(-1, 1)
dfcomb['BsmtFinType2'] = enc.fit_transform(tmp,y=None)

HeatQC = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5]]
enc = OrdinalEncoder()
enc.fit(HeatQC)
tmp = dfcomb['HeatingQC'].values.reshape(-1, 1)
dfcomb['HeatingQC'] = enc.fit_transform(tmp,y=None)

KitcQC = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5]]
enc = OrdinalEncoder()
enc.fit(KitcQC)
tmp = dfcomb['KitchenQual'].values.reshape(-1, 1)
dfcomb['KitchenQual'] = enc.fit_transform(tmp,y=None)

Functi = [['Typ',1],['Min1',2],['Min2',3],['Mod',4],['Maj1',5],['Maj2',6],['Sev',7],['Sal',8]]
enc = OrdinalEncoder()
enc.fit(Functi)
tmp = dfcomb['Functional'].values.reshape(-1, 1)
dfcomb['Functional'] = enc.fit_transform(tmp,y=None)

GarFin = [['Fin',1],['RFn',2],['Unf',3],['NA',4]]
enc = OrdinalEncoder()
enc.fit(GarFin)
tmp = dfcomb['GarageFinish'].values.reshape(-1, 1)
dfcomb['GarageFinish'] = enc.fit_transform(tmp,y=None)

GaraQC = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5],['NA',6]]
enc = OrdinalEncoder()
enc.fit(GaraQC)
tmp = dfcomb['GarageQual'].values.reshape(-1, 1)
dfcomb['GarageQual'] = enc.fit_transform(tmp,y=None)

GaCond = [['Ex',1],['Gd',2],['TA',3],['Fa',4],['Po',5],['NA',6]]
enc = OrdinalEncoder()
enc.fit(GaCond)
tmp = dfcomb['GarageCond'].values.reshape(-1, 1)
dfcomb['GarageCond'] = enc.fit_transform(tmp,y=None)

# %% [markdown]
# #### That was a pain. Separate Training/Testing Sets now that pre-processing is done.

# %%
trainrows = dfcomb['train'] == 1
dftrain = dfcomb[trainrows]
testrows = dfcomb['train'] == 0
dftest = dfcomb[testrows]

# %% [markdown]
# #### check we have same number of features

# %%
dftrain.shape
# Out:
# (1460, 215)

# %%
dftest.shape
# Out:
# (1459, 215)

# %% [markdown]
# ## Train a model

# %%
# Utility function to report best scores
def report(results, n_top=3):
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 30, random_state = 42)

# run randomized search
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 10, stop = 100, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
n_iter_search = 10
random_search = RandomizedSearchCV(rf, param_distributions=random_grid,
                                   n_iter=n_iter_search, cv=10, iid=False)
rfrandom_search.fit(dftrain,y)
report(rfrandom_search.cv_results_)
# Out:
# Model with rank: 1
# Mean validation score: 0.862 (std: 0.044)
# Parameters: {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'bootstrap': True}
#
# Model with rank: 2
# Mean validation score: 0.860 (std: 0.033)
# Parameters: {'n_estimators': 20, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 40, 'bootstrap': False}
#
# Model with rank: 3
# Mean validation score: 0.858 (std: 0.049)
# Parameters: {'n_estimators': 90, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 40, 'bootstrap': True}

# %%
# RF best result:
# Model with rank: 1
# Mean validation score: 0.862 (std: 0.044)
# Parameters: {'n_estimators': 50, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'bootstrap': True}

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
# prepare a range of alpha values to test
alphas = np.array([1000,100,10,1,0.1,0.01,0.001,0.0001,0])
ridge = Ridge()
ridgegrid = GridSearchCV(estimator=ridge, param_grid=dict(alpha=alphas),cv=10)
ridgegrid.fit(dftrain,y)
print(ridgegrid)
# summarize the results of the grid search
print(ridgegrid.best_score_)
print(ridgegrid.best_estimator_.alpha)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': array([1.e+03, 1.e+02, 1.e+01, 1.e+00, 1.e-01, 1.e-02, 1.e-03, 1.e-04,
#        0.e+00])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
# 0.8447483864822303
# 10.0

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()
alphas = np.array([1000,100,10,1,0.1,0.01,0.001,0.0001])
lassogrid = GridSearchCV(estimator=lasso, param_grid=dict(alpha=alphas),cv=10)
lassogrid.fit(dftrain,y)
print(lassogrid)
# summarize the results of the grid search
print(lassogrid.best_score_)
print(lassogrid.best_estimator_.alpha)
# Out:
# C:\Users\noahm\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13063797256.56189, tolerance: 852398977.1246126
#   positive)
# C:\Users\noahm\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5230649760.354614, tolerance: 827439703.8697118
#   positive)
# C:\Users\noahm\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2388496594.694702, tolerance: 829042909.2707292
#   positive)
# ...

# %%
from sklearn.linear_model import SGDRegressor
alphas = np.array([10,1,0.1,0.01,0.001,0.0001])
sgd = SGDRegressor(max_iter=1000, tol=1e-3,learning_rate='optimal')
sgdgrid = GridSearchCV(estimator=sgd, param_grid=dict(alpha=alphas),cv=10)
sgdgrid.fit(dftrain,y)
print(sgdgrid)
# summarize the results of the grid search
print(sgdgrid.best_score_)
print(sgdgrid.best_estimator_.alpha)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=SGDRegressor(alpha=0.0001, average=False,
#                                     early_stopping=False, epsilon=0.1,
#                                     eta0=0.01, fit_intercept=True,
#                                     l1_ratio=0.15, learning_rate='optimal',
#                                     loss='squared_loss', max_iter=1000,
#                                     n_iter_no_change=5, penalty='l2',
#                                     power_t=0.25, random_state=None,
#                                     shuffle=True, tol=0.001,
#                                     validation_fraction=0.1, verbose=0,
#                                     warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'alpha': array([1.e+01, 1.e+00, 1.e-01, 1.e-02, 1.e-03, 1.e-04])},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
# ...

# %% [markdown]
# #### Prep Submission with best result, random forest

# %%
rfrandom_search.best_params_

# %%
rffinal = RandomForestRegressor(n_estimators=50,min_samples_split=5,min_samples_leaf=2,max_features='auto',max_depth=None,bootstrap=True)
rffinal.fit(dftrain,y)
dftesty = rffinal.predict(dftest)
# Out:
# (1459,)

# %%
submission = pd.DataFrame({'Id': dftest['Id'],'SalePrice':dftesty})
submission.to_csv('HousePrices_submission.csv',index=False)
